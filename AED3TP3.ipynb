# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
t1 = pd.read_csv("./salida/clusteringSWEEP-SET-Av2.csv", index_col="n")
t1["diferencia-costo"] = t1["costo-sol"] - t1["costo-opt"]
t1["diferencia-k"] = t1["k-sol"] - t1["k-opt"]
t1
#listaPlot = [i for i in range()]
#xticks=listaPlot,
# Out:
#     Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  k-sol  \
# n
# 34   A-n34-k5               100      5        778     SWEEP    872.491      5
# 37   A-n37-k6               100      6        949     SWEEP   1209.260      7
# 39   A-n39-k6               100      6        831     SWEEP   1077.090      6
# 44   A-n44-k6               100      6        937     SWEEP   1138.880      6
# 45   A-n45-k7               100      7       1146     SWEEP   1382.290      7
# 48   A-n48-k7               100      7       1073     SWEEP   1291.050      7
# 53   A-n53-k7               100      7       1010     SWEEP   1219.710      7
# 55   A-n55-k9               100      9       1073     SWEEP   1295.530     10
# 60   A-n60-k9               100      9       1354     SWEEP   1671.090     10
# 65   A-n65-k9               100      9       1174     SWEEP   1349.150     10
# 69   A-n69-k9               100      9       1159     SWEEP   1367.230      9
# ...

# %%
graf1 = t1[["costo-sol", "costo-opt"]].plot(figsize=(10, 5), grid=True, title="Comparación de los costos del algoritmo sweep con el costo optimo del SET A")
graf1.set_xlabel("Cantidad de clientes")
graf1.set_ylabel("Costo de la solución")
graf1.legend(["Costo Algortimo sweep","Costo Optimo"])
plt.savefig("COMPARACION-SWEEP-SET-A.pdf")

# %%
#NO HAY NADA ACÁ JAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA

# %%
t2 = pd.read_csv("./salida/clusteringSWEEP-SET-Bv2.csv", index_col="n")
t2["diferencia-costo"] = t2["costo-sol"] - t2["costo-opt"]
t2["diferencia-k"] = t2["k-sol"] - t2["k-opt"]
t2
# Out:
#     Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  k-sol  \
# n
# 31   B-n31-k5               100      5        672     SWEEP    713.485      5
# 34   B-n34-k5               100      5        788     SWEEP    942.510      6
# 35   B-n35-k5               100      5        955     SWEEP   1123.100      5
# 38   B-n38-k6               100      6        805     SWEEP    929.287      6
# 39   B-n39-k5               100      5        549     SWEEP    680.651      5
# 41   B-n41-k6               100      6        829     SWEEP   1058.670      7
# 43   B-n43-k6               100      6        742     SWEEP    893.189      6
# 44   B-n44-k7               100      7        909     SWEEP   1233.270      8
# 45   B-n45-k5               100      5        751     SWEEP    837.149      6
# 50   B-n50-k7               100      7        741     SWEEP    886.231      7
# 51   B-n51-k7               100      7       1032     SWEEP   1239.150      8
# ...

# %%
graf2 = t2[["costo-sol", "costo-opt"]].plot(figsize=(10, 5), grid=True, title="Comparación de los costos del algoritmo sweep con el costo optimo del SET B")
graf2.set_xlabel("Cantidad de clientes")
graf2.set_ylabel("Costo de la solución")
graf2.legend(["Costo Algortimo sweep","Costo Optimo"])
plt.savefig("COMPARACION-SWEEP-SET-B.pdf")

# %%
t3 = pd.read_csv("./salida/clusteringSWEEP-SET-E.csv", index_col="n")
t3["diferencia-costo"] = t3["costo-sol"] - t3["costo-opt"]
t3["diferencia-k"] = t3["k-sol"] - t3["k-opt"]
t3
# Out:
#       Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  \
# n
# 22     E-n22-k4              6000      4        375     SWEEP    481.504
# 23     E-n23-k3              4500      3        569     SWEEP    697.365
# 30     E-n30-k3              4500      3        534     SWEEP    584.812
# 33     E-n33-k4              8000      4        835     SWEEP   1084.240
# 51     E-n51-k5               160      5        521     SWEEP    688.249
# 76     E-n76-k8               180      8        735     SWEEP    906.812
# 101  E-n101-k14               112     14       1071     SWEEP   1277.520
#
#      k-sol  tiempo  diferencia-costo  diferencia-k
# n
# 22       4     5.0           106.504             0
# 23       3     5.0           128.365             0
# 30       3     7.5            50.812             0
# 33       5     7.5           249.240             1
# 51       6    12.5           167.249             1
# 76       8    16.0           171.812             0
# ...

# %%
graf2 = t3[["costo-sol", "costo-opt"]].plot(figsize=(10, 5), grid=True, title="Comparación de los costos del algoritmo sweep con el costo optimo del SET E")
graf2.set_xlabel("Cantidad de clientes")
graf2.set_ylabel("Costo de la solución")
graf2.legend(["Costo Algortimo sweep","Costo Optimo"])
plt.savefig("COMPARACION-SWEEP-SET-E.pdf")

# %%
t4 = pd.read_csv("./salida/clusteringSWEEP-SET-Mv2v1.csv", index_col="n")
t4["diferencia-costo"] = t4["costo-sol"] - t4["costo-opt"]
t4["diferencia-k"] = t4["k-sol"] - t4["k-opt"]
t4
# Out:
#       Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  \
# n
# 101  M-n101-k10               200     10        820     SWEEP    1098.58
# 121   M-n121-k7               200      7       1034     SWEEP    1426.19
# 151  M-n151-k12               200     12       1053     SWEEP    1285.96
# 200  M-n200-k16               200     16       1274     SWEEP    1557.89
#
#      k-sol  tiempo  diferencia-costo  diferencia-k
# n
# 101     10     210            278.58             0
# 121      8     250            392.19             1
# 151     12     325            232.96             0
# 200     17     433            283.89             1

# %%
graf2 = t4[["costo-sol", "costo-opt"]].plot(figsize=(10, 5), grid=True, title="Comparación de los costos del algoritmo sweep con el costo optimo del SET M")
graf2.set_xlabel("Cantidad de clientes")
graf2.set_ylabel("Costo de la solución")
graf2.legend(["Costo Algortimo sweep","Costo Optimo"])
plt.savefig("COMPARACION-SWEEP-SET-M.pdf")

# %%
t5 = pd.read_csv("./salida/clusteringSWEEP-SET-Pv2v1.csv", index_col="n")
t5["diferencia-costo"] = t5["costo-sol"] - t5["costo-opt"]
t5["diferencia-k"] = t5["k-sol"] - t5["k-opt"]
t5
# Out:
#      Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  \
# n
# 16    P-n16-k8                35      8        450     SWEEP    556.957
# 19    P-n19-k2               160      2        212     SWEEP    297.234
# 20    P-n20-k2               160      2        216     SWEEP    305.400
# 22    P-n22-k2               160      2        216     SWEEP    254.961
# 23    P-n23-k8                40      8        529     SWEEP    660.120
# 40    P-n40-k5               140      5        458     SWEEP    541.377
# 45    P-n45-k5               150      5        510     SWEEP    636.033
# 50    P-n50-k7               150      7        554     SWEEP    665.178
# 55    P-n55-k8               160      8        588     SWEEP    690.277
# 60   P-n60-k10               120     10        744     SWEEP    896.108
# 70   P-n70-k10               135     10        827     SWEEP    981.875
# 76    P-n76-k4               350      4        593     SWEEP    796.958
# ...

# %%
graf2 = t5[["costo-sol", "costo-opt"]].plot(figsize=(10, 5), grid=True, title="Comparación de los costos del algoritmo sweep con el costo optimo del SET P")
graf2.set_xlabel("Cantidad de clientes")
graf2.set_ylabel("Costo de la solución")
graf2.legend(["Costo Algortimo sweep","Costo Optimo"])
plt.savefig("COMPARACION-SWEEP-SET-P.pdf")

# %%
t5 = pd.read_csv("./salida/clusteringSWEEP-SET-X.csv", index_col="n")
t5["diferencia-costo"] = t5["costo-sol"] - t5["costo-opt"]
t5["diferencia-k"] = t5["k-sol"] - t5["k-opt"]
t5
# Out:
#       Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  \
# n
# 153  X-n153-k22               144     22      21220     SWEEP    29902.2
# 167  X-n167-k10               133     10      20557     SWEEP    25285.7
# 176  X-n176-k26               142     26      47812     SWEEP    69232.0
# 186  X-n186-k15               974     15      24145     SWEEP    29251.0
#
#      k-sol  tiempo  diferencia-costo  diferencia-k
# n
# 153     30     318            8682.2             8
# 167     10     334            4728.7             0
# 176     34     344           21420.0             8
# 186     15     355            5106.0             0

# %%
#AHORA VIENEN LOS TIEMPOS

# %%
tD = pd.read_csv("./salida/clusteringSWEEP-SET-DIEGO.csv", index_col="n")
tD["diferencia-costo"] = tD["costo-sol"] - tD["costo-opt"]
tD["diferencia-k"] = tD["k-sol"] - tD["k-opt"]
tD["%-desvio-costo"] = (tD["diferencia-costo"] * 100) / tD["costo-opt"]
tD = tD.sort_index()
tD
# Out:
#       Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  \
# n
# 16     P-n16-k8                35      8        450     SWEEP    556.957
# 20     P-n20-k2               160      2        216     SWEEP    305.400
# 22     P-n22-k2               160      2        216     SWEEP    254.961
# 22     E-n22-k4              6000      4        375     SWEEP    481.504
# 23     P-n23-k8                40      8        529     SWEEP    660.120
# 23     E-n23-k3              4500      3        569     SWEEP    697.365
# 30     E-n30-k3              4500      3        534     SWEEP    584.812
# 31     B-n31-k5               100      5        672     SWEEP    713.485
# 32     A-n32-k5               100      5        784     SWEEP   1098.650
# 34     B-n34-k5               100      5        788     SWEEP    942.510
# 35     B-n35-k5               100      5        955     SWEEP   1123.100
# 36     A-n36-k5               100      5        799     SWEEP    985.325
# ...

# %%
t11 = t1
t11["complejidad"] = t11["tiempo"] / (t11.index **2)
t11
# Out:
#     Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  k-sol  \
# n
# 34   A-n34-k5               100      5        778     SWEEP    872.491      5
# 37   A-n37-k6               100      6        949     SWEEP   1209.260      7
# 39   A-n39-k6               100      6        831     SWEEP   1077.090      6
# 44   A-n44-k6               100      6        937     SWEEP   1138.880      6
# 45   A-n45-k7               100      7       1146     SWEEP   1382.290      7
# 48   A-n48-k7               100      7       1073     SWEEP   1291.050      7
# 53   A-n53-k7               100      7       1010     SWEEP   1219.710      7
# 55   A-n55-k9               100      9       1073     SWEEP   1295.530     10
# 60   A-n60-k9               100      9       1354     SWEEP   1671.090     10
# 65   A-n65-k9               100      9       1174     SWEEP   1349.150     10
# 69   A-n69-k9               100      9       1159     SWEEP   1367.230      9
# ...

# %%
graf2 = t11[["complejidad"]].plot(figsize=(10, 5), grid=True, title="Complejidad del Algortimo Sweep (SET-A)")
graf2.set_xlabel("Cantidad de clientes")
graf2.set_ylabel("Tiempo para calcular caminos (ms)")
graf2.legend(["tiempo/n^2"])
plt.savefig("COMPLEJIDAD-SET-A.pdf")

# %%
t22 = t2
t22["complejidad"] = t22["tiempo"] / (t22.index **2)
t22
# Out:
#     Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  k-sol  \
# n
# 31   B-n31-k5               100      5        672     SWEEP    713.485      5
# 34   B-n34-k5               100      5        788     SWEEP    942.510      6
# 35   B-n35-k5               100      5        955     SWEEP   1123.100      5
# 38   B-n38-k6               100      6        805     SWEEP    929.287      6
# 39   B-n39-k5               100      5        549     SWEEP    680.651      5
# 41   B-n41-k6               100      6        829     SWEEP   1058.670      7
# 43   B-n43-k6               100      6        742     SWEEP    893.189      6
# 44   B-n44-k7               100      7        909     SWEEP   1233.270      8
# 45   B-n45-k5               100      5        751     SWEEP    837.149      6
# 50   B-n50-k7               100      7        741     SWEEP    886.231      7
# 51   B-n51-k7               100      7       1032     SWEEP   1239.150      8
# ...

# %%
graf2 = t22[["complejidad"]].plot(figsize=(10, 5), grid=True, title="Complejidad del Algortimo Sweep (SET-B)")
graf2.set_xlabel("Cantidad de clientes")
graf2.set_ylabel("Tiempo para calcular caminos (ms)")
graf2.legend(["tiempo/n^2"])
plt.savefig("COMPLEJIDAD-SET-B.pdf")

# %%
t33 = t3
t33["complejidad"] = t33["tiempo"] / (t33.index **2)
t33
# Out:
#       Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  \
# n
# 22     E-n22-k4              6000      4        375     SWEEP    481.504
# 23     E-n23-k3              4500      3        569     SWEEP    697.365
# 30     E-n30-k3              4500      3        534     SWEEP    584.812
# 33     E-n33-k4              8000      4        835     SWEEP   1084.240
# 51     E-n51-k5               160      5        521     SWEEP    688.249
# 76     E-n76-k8               180      8        735     SWEEP    906.812
# 101  E-n101-k14               112     14       1071     SWEEP   1277.520
#
#      k-sol  tiempo  diferencia-costo  diferencia-k  complejidad
# n
# 22       4     5.0           106.504             0     0.010331
# 23       3     5.0           128.365             0     0.009452
# 30       3     7.5            50.812             0     0.008333
# 33       5     7.5           249.240             1     0.006887
# ...

# %%
graf2 = t33[["complejidad"]].plot(figsize=(10, 5), grid=True, title="Complejidad del Algortimo Sweep (SET-E)")
graf2.set_xlabel("Cantidad de clientes")
graf2.set_ylabel("Tiempo para calcular caminos (ms)")
graf2.legend(["tiempo/n^2"])
plt.savefig("COMPLEJIDAD-SET-E.pdf")

# %%
t44 = t4
t44["complejidad"] = t44["tiempo"] / (t44.index **2)
t44
# Out:
#       Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  \
# n
# 101  M-n101-k10               200     10        820     SWEEP    1098.58
# 121   M-n121-k7               200      7       1034     SWEEP    1426.19
# 151  M-n151-k12               200     12       1053     SWEEP    1285.96
# 200  M-n200-k16               200     16       1274     SWEEP    1557.89
#
#      k-sol  tiempo  diferencia-costo  diferencia-k  complejidad
# n
# 101     10     210            278.58             0     0.020586
# 121      8     250            392.19             1     0.017075
# 151     12     325            232.96             0     0.014254
# 200     17     433            283.89             1     0.010825

# %%
graf2 = t44[["complejidad"]].plot(figsize=(10, 5), grid=True, title="Complejidad del Algortimo Sweep (SET-M)")
graf2.set_xlabel("Cantidad de clientes")
graf2.set_ylabel("Tiempo para calcular caminos (ms)")
graf2.legend(["tiempo/n^2"])
plt.savefig("COMPLEJIDAD-SET-M.pdf")

# %%
t55 = t5
t55["complejidad"] = t55["tiempo"] / (t55.index **2)
t55
# Out:
#      Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  \
# n
# 16    P-n16-k8                35      8        450     SWEEP    556.957
# 19    P-n19-k2               160      2        212     SWEEP    297.234
# 20    P-n20-k2               160      2        216     SWEEP    305.400
# 22    P-n22-k2               160      2        216     SWEEP    254.961
# 23    P-n23-k8                40      8        529     SWEEP    660.120
# 40    P-n40-k5               140      5        458     SWEEP    541.377
# 45    P-n45-k5               150      5        510     SWEEP    636.033
# 50    P-n50-k7               150      7        554     SWEEP    665.178
# 55    P-n55-k8               160      8        588     SWEEP    690.277
# 60   P-n60-k10               120     10        744     SWEEP    896.108
# 70   P-n70-k10               135     10        827     SWEEP    981.875
# 76    P-n76-k4               350      4        593     SWEEP    796.958
# ...

# %%
graf2 = t55[["complejidad"]].plot(figsize=(10, 5), grid=True, title="Complejidad del Algortimo Sweep (SET-P)")
graf2.set_xlabel("Cantidad de clientes")
graf2.set_ylabel("Tiempo para calcular caminos (ms)")
graf2.legend(["tiempo/n^2"])
plt.savefig("COMPLEJIDAD-SET-P.pdf")

# %%
tC = pd.read_csv("./salida/clusteringSWEEP-SET-COMP-BIGNv2.csv", index_col="n")
tC["diferencia-costo"] = tC["costo-sol"] - tC["costo-opt"]
tC["diferencia-k"] = tC["k-sol"] - tC["k-opt"]
#tC["%-desvio-costo"] = (tD["diferencia-costo"] * 100) / tD["costo-opt"]
#tC = tD.sort_index()
tC["complejidad"] = tC["tiempo"] / (tC.index **2)
tC
# Out:
#         Instancia  capacidad-camion  k-opt  costo-opt Algoritmo  costo-sol  \
# n
# 513    X-n513-k21               142     21      24201     SWEEP    31461.8
# 548    X-n548-k50                11     50      86701     SWEEP   109727.0
# 613    X-n613-k62               523     62      59556     SWEEP    75190.6
# 655   X-n655-k131                 5    131     106780     SWEEP   125556.0
# 716    X-n716-k35              1007     35      43414     SWEEP    54836.8
# 749    X-n749-k98               396     98      77365     SWEEP   105400.0
# 819   X-n819-k171               358    171     158265     SWEEP   194845.0
# 856    X-n856-k95                 9     95      89002     SWEEP   103908.0
# 916   X-n916-k207                33    207     329247     SWEEP   453515.0
# 957    X-n957-k87                11     87      85478     SWEEP   113454.0
# 1001  X-n1001-k43               131     43      72402     SWEEP    92308.3
#
# ...

# %%
graf2 = tC[["complejidad"]].plot(figsize=(10, 5), grid=True, title="Complejidad del Algortimo Sweep con valores de n grandes")
graf2.set_xlabel("Cantidad de clientes")
graf2.set_ylabel("Tiempo para calcular caminos (ms)")
graf2.legend(["tiempo/n^2"])
plt.savefig("COMPLEJIDAD-SET-BIGN.pdf")
